# %%
from pandas import DataFrame
import pymysql
import pandas as pd
import pandas.io.sql as psql
pymysql.install_as_MySQLdb()
import MySQLdb
from sqlalchemy import create_engine

# %%
data = pd.read_csv('data_file/seoul_dobong.csv', encoding = "cp949", header = None, index = False)

# %%
data = pd.read_csv('data_file/seoul_yangcheon.csv', encoding = "cp949", header = None, index = False)

# %%
columns = ['CityHollName', 'RoadAddress', 'Address', 'Purpose', 
          'NumCamera', 'Pixel', 'Direction', 'DaysToKeep', 'SetDate', 
          'PhoneNumber', 'Latitude', 'Longitude', 'DataDate']

# %%
data.columns = columns
data[1:]

# %%
engine = create_engine("mysql+mysqldb://root:"+"kpy680126"+"@localhost/cctv", encoding='cp949')
conn = engine.connect()

# %%
data[1:].to_sql(name='Dobong', con=engine, if_exists='append', index = False)
